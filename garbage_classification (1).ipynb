# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-44ea9dcf-20ac-4664-af9a-3a80d8f531a9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-44ea9dcf-20ac-4664-af9a-3a80d8f531a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile("garbage-classification.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/")

# %%
import os
print(os.path.exists("/content/garbage-classification.zip"))
# Out:
# True

# %%
os.listdir("/content/")
# Out:
# ['.config',
#  'garbage-classification',
#  'garbage-classification (1).zip',
#  'garbage-classification.zip',
#  'sample_data']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# If folder name is different, replace below
data_dir = "/content/garbage-classification.zip"

datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_data = datagen.flow_from_directory(
    data_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data = datagen.flow_from_directory(
    data_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# /tmp/ipython-input-8-2615159877.py in <cell line: 0>()
#       6 datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
#       7
# ----> 8 train_data = datagen.flow_from_directory(
#       9     data_dir,
#      10     target_size=(150, 150),
#
# /usr/local/lib/python3.11/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1136         keep_aspect_ratio=False,
#    1137     ):
# -> 1138         return DirectoryIterator(
#    1139             directory,
#    1140             self,
#
# ...

# %%
data_dir = "/content/garbage-classification-"

# %%
import os
os.listdir("/content/")
# Out:
# ['.config',
#  'garbage-classification',
#  '.ipynb_checkpoints',
#  'garbage-classification.zip',
#  'sample_data']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_data = datagen.flow_from_directory(
    data_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data = datagen.flow_from_directory(
    data_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-12-2962711822.py in <cell line: 0>()
#       3 datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
#       4
# ----> 5 train_data = datagen.flow_from_directory(
#       6     data_dir,
#       7     target_size=(150, 150),
#
# /usr/local/lib/python3.11/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1136         keep_aspect_ratio=False,
#    1137     ):
# -> 1138         return DirectoryIterator(
#    1139             directory,
#    1140             self,
#
# ...

# %%
import os

# Show everything inside /content/
for item in os.listdir("/content/"):
    path = os.path.join("/content", item)
    print(f"{item} --> {'DIR' if os.path.isdir(path) else 'FILE'}")
# Out:
#   File "/tmp/ipython-input-13-711316997.py", line 6
#     print(f"{item} --> {'DIR' if os.path.isdir(path) else 'FILE'}")
#                              ^
# SyntaxError: invalid non-printable character U+00A0

# %%
import os

for item in os.listdir("/content/"):
    print(repr(item))  # shows hidden characters like spaces, dashes
# Out:
# '.config'
# 'garbage-classification'
# '.ipynb_checkpoints'
# 'garbage-classification.zip'
# 'sample_data'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_data = datagen.flow_from_directory(
    data_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data = datagen.flow_from_directory(
    data_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
 subset='validation'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-15-1580295650.py in <cell line: 0>()
#       3 datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
#       4
# ----> 5 train_data = datagen.flow_from_directory(
#       6     data_dir,
#       7     target_size=(150, 150),
#
# /usr/local/lib/python3.11/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1136         keep_aspect_ratio=False,
#    1137     ):
# -> 1138         return DirectoryIterator(
#    1139             directory,
#    1140             self,
#
# ...

# %%
import zipfile
import os

# Unzip the file (make sure you've uploaded it)
with zipfile.ZipFile('/content/garbage-classification.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')

# Now check what's inside
os.listdir('/content/garbage-classification')
# Out:
# ['cardboard',
#  'README.md',
#  'plastic',
#  '.git',
#  'metal',
#  'paper',
#  'trash',
#  'glass',
#  'cardboard1.jpg',
#  'cardboard401.jpg',
#  'cardboard398.jpg']

# %%
train_generator = datagen.flow_from_directory(
    '/content/garbage-classification',  # or whatever folder has class subfolders
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 18 images belonging to 7 classes.

# %%
model.fit(train_generator, epochs=10)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.1111 - loss: 1.9530
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 696ms/step - accuracy: 0.1667 - loss: 8.0786
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 768ms/step - accuracy: 0.1667 - loss: 8.4872
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 720ms/step - accuracy: 0.2778 - loss: 6.9933
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1667 - loss: 3.8856
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 733ms/step - accuracy: 0.5000 - loss: 1.7273
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 680ms/step - accuracy: 0.5000 - loss: 1.4996
# Epoch 8/10
# ...

# %%
model.evaluate(validation_generator)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-24-2142905844.py in <cell line: 0>()
# ----> 1 model.evaluate(validation_generator)
#
# NameError: name 'validation_generator' is not defined

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Step 1: Create ImageDataGenerator with split
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # 20% for validation
)

# Step 2: Training generator (80%)
train_generator = datagen.flow_from_directory(
    '/content/garbage-classification',
    target_size=(150, 150),
    batch_size=1,
    class_mode='categorical',
    subset='training',
    shuffle=True# 👈 Training subset
)

# Step 3: Validation generator (20%)
validation_generator = datagen.flow_from_directory(
    '/content/garbage-classification',
    target_size=(150, 150),
    batch_size=1,
    class_mode='categorical',
    subset='validation',
    shuffle=True  # 👈 Validation subset
)
# Out:
# Found 18 images belonging to 7 classes.
# Found 0 images belonging to 7 classes.

# %%
 model.fit(
     train_generator,
    epochs=10
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.6560 - loss: 1.2131
# Epoch 2/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 230ms/step - accuracy: 0.6318 - loss: 1.0637
# Epoch 3/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.9421 - loss: 0.7065
# Epoch 4/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - accuracy: 0.9226 - loss: 0.9676
# Epoch 5/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.6451 - loss: 1.4308
# Epoch 6/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - accuracy: 0.9041 - loss: 0.3217
# Epoch 7/10
# ...

# %%
model.save("garbage_classification_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

img = image.load_img('/content/garbage-classification', target_size=(150, 150))  # Replace with your test image path
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0

prediction = model.predict(img_array)
predicted_class = np.argmax(prediction)

# Get class labels
class_names = list(train_generator.class_indices.keys())
print("Predicted Class:", class_names[predicted_class])

# %%
from google.colab import files

# Download notebook
files.download('garbage_classification_model.h5')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7dc2e68d-35c7-4874-8871-ec06bc8cb5ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7dc2e68d-35c7-4874-8871-ec06bc8cb5ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Step 1: Create the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(128, activation='relu'),
    Dense(7, activation='softmax')  # 7 classes
])

# Step 2: Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
